# %%
# %cd ../
# Out:
# C:\Users\kotak\Documents\work\Descriptors

# %%
# %run -i Descriptor_ver1.0.1.py ./sdf/blined_humancl_95_test_1482.sdf ./csv/test.csv 2D
# Out:
# RDKit WARNING: [21:31:36] Enabling RDKit 2019.09.3 jupyter extensions
#   6%|▊            | 6/94 [00:03<00:55,  1.58it/s]
# C:\Users\kotak\Miniconda3\envs\RDkit\lib\site-packages\numpy\core\fromnumeric.py:90: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# 100%|████████████| 94/94 [00:22<00:00,  4.11it/s]
# Columns size:  1614

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./csv/test.csv')
df
# Out:
#     index        ABC      ABCGG  nAcid  nBase    SpAbs_A   SpMax_A  SpDiam_A  \
# 0       0  15.722758  13.544088    0.0    1.0  26.760107  2.368096  4.736193
# 1       1  18.549286  15.367887    0.0    1.0  30.757331  2.553378  5.003522
# 2       2  24.165701  19.978681    0.0    1.0  41.742357  2.453835  4.907669
# 3       3  17.872588  14.857897    1.0    0.0  29.447228  2.482065  4.964130
# 4       4   7.574585   7.808351    0.0    0.0  11.335494  2.437530  4.644140
# ..    ...        ...        ...    ...    ...        ...       ...       ...
# 89     90  15.124891  13.106521    0.0    1.0  25.183738  2.432105  4.864209
# 90     91  17.865098  14.583318    0.0    1.0  28.157662  2.577832  5.155242
# 91     92  47.239715  36.382733    0.0    2.0  77.343880  2.795909  5.480854
# 92     93  47.837432  36.983167    0.0    2.0  78.750491  2.798422  5.484227
# 93     94  14.308545  12.811280    0.0    0.0  23.747937  2.438920  4.799979
#
# ...

# %%
categorical_feature_list = []
for i in df.columns.tolist():
    s = df[i]
    if len(s.unique()) <= 11 and len(s.unique()) > 2:
        print(i)
        categorical_feature_list.append(i)
# Out:
# nAcid
# nBase
# nAromAtom
# nAromBond
# nBridgehead
# nN
# nS
# nF
# nCl
# nX
# nBondsD
# nBondsA
# C2SP1
# C1SP2
# C3SP2
# C1SP3
# C3SP3
# C4SP3
# Xch-3d
# Xch-4d
# Xch-3dv
# Xch-4dv
# NsCH3
# NdsCH
# NsssCH
# NtsC
# NdssC
# NaasC
# NssssC
# NsNH2
# NssNH
# NsssNH
# NdsN
# NaaN
# NsssN
# NddsN
# NaasN
# NsOH
# NdO
# NssO
# NsF
# NssS
# NaaS
# NsCl
# SdCH2
# StsC
# SsNH3
# SssNH2
# StN
# SddsN
# SaaO
# SsF
# SdsssP
# SddssS
# SsCl
# MAXdCH2
# MAXtsC
# MAXsNH3
# MAXssNH2
# MAXtN
# MAXddsN
# MAXaaO
# MAXsF
# MAXdsssP
# MAXddssS
# MAXsCl
# MINdCH2
# MINtsC
# MINsNH3
# MINssNH2
# MINtN
# MINddsN
# MINaaO
# MINsF
# MINdsssP
# MINddssS
# MINsCl
# ETA_beta_ns_d
# nHBDon
# SlogP_VSA7
# SlogP_VSA11
# MDEC-44
# MDEN-11
# nRing
# n4Ring
# n5Ring
# n6Ring
# nHRing
# n4HRing
# n5HRing
# n6HRing
# naRing
# n5aRing
# n6aRing
# naHRing
# n5aHRing
# n6aHRing
# nARing
# n4ARing
# n5ARing
# n6ARing
# nAHRing
# n4AHRing
# n5AHRing
# n6AHRing
# nFRing
# nG12FRing
# nFHRing
# nG12FHRing
# nFARing
# ...

# %% [markdown]
# #### ↑これだけでCatBoostならターゲットエンコーディングできるのでやってみる

# %%
def target_encorgind(categorical_feature_list, df):
    for feature in categorical_feature_list:
        s_feature = df[feature]
        category = list(s_feature.unique())
        for cate in category:
                    
    
    return df

# %% [markdown]
# ## Target encording はデータのリークに注意

# %%
list(df['nCl'].unique())
# Out:
# [0.0, 1.0, 2.0]
